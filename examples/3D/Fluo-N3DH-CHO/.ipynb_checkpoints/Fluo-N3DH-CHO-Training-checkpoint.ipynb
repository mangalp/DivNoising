# %% [markdown]
# # DivNoising - Training
# This notebook contains an example on how to train a 3D DivNoising VAE. This notebook illustrates the example for Fluo-N3DH-CHO data which is artificially corrupted by gaussian noise.

# %%
# We import all our dependencies.
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch.utils.data import Dataset, DataLoader
from torch.nn import init
import os
import glob
from tifffile import imread
from matplotlib import pyplot as plt

import sys
sys.path.append('../../../')
from divnoising import dataLoader
from divnoising import utils
from divnoising import training
from nets import model
from divnoising import histNoiseModel
from divnoising.gaussianMixtureNoiseModel import GaussianMixtureNoiseModel

import urllib
import os
import zipfile

from tqdm import tqdm

# %%
device = torch.device("cuda:0")

# %% [markdown]
# ### Download data
#
# Download the data from https://owncloud.mpi-cbg.de/index.php/s/LgRJOWmk9JV1BRU. Here we show the pipeline for Fluo-N3DH-CHO dataset from Cell Tracking Challenge. Save the dataset in an appropriate path. For us, the path is the data folder which exists at `../../../`.

# %%
if not os.path.isdir('./data'):
    os.mkdir('./data')

zipPath="./data/Fluo-N3DH-CHO_01.zip"
if not os.path.exists(zipPath):  
    data = urllib.request.urlretrieve('https://owncloud.mpi-cbg.de/index.php/s/LgRJOWmk9JV1BRU/download', zipPath)
    with zipfile.ZipFile(zipPath, 'r') as zip_ref:
        zip_ref.extractall("./data")

# %% [markdown]
# ### Specify ```path``` to load data
# Your data should be stored in the directory indicated by ```path```.

# %%
path="./data/Fluo-N3DH-CHO_01/"
file_names = sorted(glob.glob(path+'*.tif'))
signal = []
for f in file_names:
    signal.append(imread(f))
signal= np.array(signal)

# %% [markdown]
# ### Add gaussian noise to create noisy inputs
# We add gaussian noise of standard deviation 15.0 to each image. You can choose to decrease/increase the amount of noise added by setting the parameter ```gaussian_noise_std``` below.

# %%
gaussian_noise_std = 15.0
observation = []
for i in range(signal.shape[0]):
    observation.append(signal[i]+np.random.randn(signal[i].shape[0], signal[i].shape[1], signal[i].shape[2])*gaussian_noise_std)
observation = np.array(observation)

# %% [markdown]
# # Training Data Preparation

# %% [markdown]
# For training we need to follow some preprocessing steps first which will prepare the data for training purposes.

# %% [markdown]
# ### Data preprocessing
# We first divide the data into training and validation sets with 85% images allocated to training set  and rest to validation set.

# %%
train_images = observation[:int(0.85*observation.shape[0])]
val_images = observation[int(0.85*observation.shape[0]):]
print("Shape of training images:", train_images.shape, "Shape of validation images:", val_images.shape)
# Out:
# Shape of training images: (78, 4, 443, 512) Shape of validation images: (14, 4, 443, 512)

# %% [markdown]
# We extract overlapping patches of size ```patch_size``` from training and validation images. Specify the parameter ```patch_size```. The number of patches to be extracted is automatically determined depending on the size of images.

# %%
patch_size = (4,128,128)

x_train_crops = utils.extract_patches_3d(train_images,shape=patch_size)
x_val_crops = utils.extract_patches_3d(val_images,shape=patch_size)

x_train_crops = np.array(x_train_crops)
x_val_crops = np.array(x_val_crops)

print("Shape of training data:", train_images.shape, "Shape of validation data:", val_images.shape)
# Out:
# Shape of training data: (78, 4, 443, 512) Shape of validation data: (14, 4, 443, 512)

# %%
# x_train_crops = utils.augment_data_3d(x_train_crops)

# %% [markdown]
# Finally, we compute the mean and standard deviation of our combined train and validation sets and do some additional preprocessing.

# %%
data_mean, data_std = utils.getMeanStdData(train_images, val_images)

x_train, x_val = utils.convertToFloat32(x_train_crops, x_val_crops)
x_train_extra_axis = x_train[:,np.newaxis]
x_val_extra_axis = x_val[:,np.newaxis]

x_train_tensor = utils.convertNumpyToTensor(x_train_extra_axis)
x_val_tensor = utils.convertNumpyToTensor(x_val_extra_axis)

# %%
print("Shape of training tensor:", x_train_tensor.shape)
# Out:
# Shape of training tensor: torch.Size([936, 1, 4, 128, 128])

# %% [markdown]
# # Configure DivNoising model

# %% [markdown]
# Here we specify some parameters of our DivNoising network needed for training. <br>
# The parameter <code>z_dim</code> specifies the size of the bottleneck dimension corresponding to each pixel. <br>
# The parameter <code>in_channels</code> specifies the number of input channels which for this dataset is 1.<br>
# We currently have support for only 1 channel input but it may be extended to arbitrary number of channels in the future. <br>
# The parameter <code>init_filters</code> specifies the number of filters in the first layer of the network. <br>
# The parameter <code>n_depth</code> specifies the depth of the network.
# The parameter <code>batch_size</code> specifies the batch size used for training. <br>
# The parameter <code>n_filters_per_depth</code> specifies the number of convolutions per depth. <br>
# The parameter <code>directory_path</code> specifies the directory where the model will be saved. <br>
# The parameter <code>n_epochs</code> specifies the number of training epochs. <br>
# The parameter <code>lr</code> specifies the learning rate. <br>
# The parameter <code>val_loss_patience</code> specifies the number of epochs after which training will be terminated if the validation loss does not decrease by a factor of 1e-6. <br>
# The parameter <code>noiseModel</code> is the noise model you want to use. Run the notebook  ```Convallaria-CreateNoiseModel.ipynb```, if you have not yet generated the noise model for this dataset yet. If set to None a Gaussian noise model is used.<br>
# The parameter <code>gaussian_noise_std</code> is the standard deviation of the Gaussian noise model. This should only be set if 'noiseModel' is None. Otherwise, if you have created a noise model already, set it to ```None```. <br>
# The parameter <code>model_name</code> specifies the name of the model with which the weights will be saved for prediction later.
#
# __Note:__ We observed good performance of the DivNosing network for most datasets with the default settings in the next cell. However, we also observed that playing with the paramaters sensibly can also improve performance.

# %%
z_dim=64
in_channels = 1
init_filters = 32
n_filters_per_depth=2
n_depth=2
batch_size=32
directory_path = "./"
n_epochs = int(22000000/(x_train_tensor.shape[0])) # A heurisitc to set the number of epochs
lr=0.001
val_loss_patience = 100
gaussian_noise_std = gaussian_noise_std
#noise_model_params= np.load("/home/krull/fileserver/experiments/ReDo/convallaria/GMMNoiseModel_convallaria_3_2_calibration.npz")
noise_model_params= None
noiseModel = None
model_name = "fluon3dh-"

# %% [markdown]
# # Train network
#
# __Note:__ We observed that for certain datasets, the KL loss goes towards 0. This phenomenon is called ```posterior collapse``` and is undesirable.
# We prevent it by aborting and restarting the training once the KL dropy below a threshold (```kl_min```).
# An alternative approach is a technique called *KL Annealing* where we increase the weight on KL divergence loss term from 0 to 1 gradually in a numer of steps.
# This cann be activated by setting the parameter ```kl_annealing``` to ```True```. <br>
# The parameter ```kl_start``` specifies the epoch when KL annelaing will start. <br>
# The parameter ```kl_annealtime``` specifies until which epoch KL annealing will be operational. <br>
# If the parameter ```kl_annealing``` is set to ```False```, the values of ```kl_start``` and  ```kl_annealtime``` are ignored.

# %%
train_dataset = dataLoader.MyDataset(x_train_tensor,x_train_tensor)
val_dataset = dataLoader.MyDataset(x_val_tensor,x_val_tensor)

trainHist, reconHist, klHist, valHist = None, None, None, None
attempts=0
while trainHist is None:
    attempts+=1
    print('start training: attempt '+ str(attempts))
    vae = model.VAE(data_dim=x_train_tensor.dim()-2,
                    z_dim=z_dim, 
                    in_channels=in_channels,
                    init_filters = init_filters, 
                    n_filters_per_depth=n_filters_per_depth,
                    n_depth=n_depth)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
    trainHist, reconHist, klHist, valHist = training.trainNetwork(net=vae, train_loader=train_loader, 
                                                                     val_loader=val_loader,
                                                                     device=device,directory_path=directory_path,
                                                                     model_name=model_name,
                                                                     n_epochs=n_epochs, batch_size=batch_size,lr=lr,
                                                                     val_loss_patience = val_loss_patience,
                                                                     kl_annealing = False,
                                                                     kl_start = 0, 
                                                                     kl_annealtime = 3,
                                                                     kl_min=1e-5,
                                                                     data_mean =data_mean,data_std=data_std, 
                                                                     noiseModel = noiseModel,
                                                                     gaussian_noise_std = gaussian_noise_std)
# Out:
# start training: attempt 1
# postersior collapse: aborting
# start training: attempt 2
# Epoch[1/23504] Training Loss: 1.402 Reconstruction Loss: 1.377 KL Loss: 0.025
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.9868285059928894 Min validation loss: 0.9868285059928894
# Time for epoch: 11seconds
# Est remaining time: 2 days, 23:48:53 or 258533 seconds
# ----------------------------------------
# Epoch[2/23504] Training Loss: 0.889 Reconstruction Loss: 0.873 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.7463371157646179 Min validation loss: 0.7463371157646179
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:20:24 or 282024 seconds
# ----------------------------------------
# Epoch[3/23504] Training Loss: 0.809 Reconstruction Loss: 0.795 KL Loss: 0.013
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.7372337579727173 Min validation loss: 0.7372337579727173
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:20:12 or 282012 seconds
# ----------------------------------------
# Epoch[4/23504] Training Loss: 0.767 Reconstruction Loss: 0.754 KL Loss: 0.013
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.6962081789970398 Min validation loss: 0.6962081789970398
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:20:00 or 282000 seconds
# ----------------------------------------
# Epoch[5/23504] Training Loss: 0.746 Reconstruction Loss: 0.731 KL Loss: 0.015
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 1 Validation Loss: 0.6965012550354004 Min validation loss: 0.6962081789970398
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:19:48 or 281988 seconds
# ----------------------------------------
# Epoch[6/23504] Training Loss: 0.732 Reconstruction Loss: 0.715 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.6845920085906982 Min validation loss: 0.6845920085906982
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:19:36 or 281976 seconds
# ----------------------------------------
# Epoch[7/23504] Training Loss: 0.723 Reconstruction Loss: 0.705 KL Loss: 0.018
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 1 Validation Loss: 0.6909583806991577 Min validation loss: 0.6845920085906982
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:19:24 or 281964 seconds
# ----------------------------------------
# Epoch[8/23504] Training Loss: 0.720 Reconstruction Loss: 0.702 KL Loss: 0.018
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.6820200681686401 Min validation loss: 0.6820200681686401
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:19:12 or 281952 seconds
# ----------------------------------------
# Epoch[9/23504] Training Loss: 0.719 Reconstruction Loss: 0.701 KL Loss: 0.018
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 1 Validation Loss: 0.6854108572006226 Min validation loss: 0.6820200681686401
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:19:00 or 281940 seconds
# ----------------------------------------
# Epoch[10/23504] Training Loss: 0.709 Reconstruction Loss: 0.691 KL Loss: 0.018
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# saving ./fluon3dh-best_vae.net
# Patience: 0 Validation Loss: 0.6751521825790405 Min validation loss: 0.6751521825790405
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:18:48 or 281928 seconds
# ----------------------------------------
# Epoch[11/23504] Training Loss: 0.708 Reconstruction Loss: 0.691 KL Loss: 0.018
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 1 Validation Loss: 0.680891752243042 Min validation loss: 0.6751521825790405
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6:18:36 or 281916 seconds
# ----------------------------------------
# Epoch[12/23504] Training Loss: 0.711 Reconstruction Loss: 0.693 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 2 Validation Loss: 0.6770246028900146 Min validation loss: 0.6751521825790405
# Time for epoch: 12seconds
# Est remaining time: 3 days, 6
Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:37:36 or 275856 seconds
# ----------------------------------------
# Epoch[517/23504] Training Loss: 0.588 Reconstruction Loss: 0.572 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 83 Validation Loss: 0.5892167091369629 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:37:24 or 275844 seconds
# ----------------------------------------
# Epoch[518/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 84 Validation Loss: 0.5943024158477783 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:37:12 or 275832 seconds
# ----------------------------------------
# Epoch[519/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 85 Validation Loss: 0.5903502702713013 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:37:00 or 275820 seconds
# ----------------------------------------
# Epoch[520/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 86 Validation Loss: 0.5904180407524109 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:36:48 or 275808 seconds
# ----------------------------------------
# Epoch[521/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 87 Validation Loss: 0.5906228423118591 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:36:36 or 275796 seconds
# ----------------------------------------
# Epoch[522/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 88 Validation Loss: 0.5913224220275879 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:36:24 or 275784 seconds
# ----------------------------------------
# Epoch[523/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 89 Validation Loss: 0.5905121564865112 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:36:12 or 275772 seconds
# ----------------------------------------
# Epoch[524/23504] Training Loss: 0.588 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 90 Validation Loss: 0.5888920426368713 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:36:00 or 275760 seconds
# ----------------------------------------
# Epoch[525/23504] Training Loss: 0.589 Reconstruction Loss: 0.573 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 91 Validation Loss: 0.5899845361709595 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:35:48 or 275748 seconds
# ----------------------------------------
# Epoch[526/23504] Training Loss: 0.588 Reconstruction Loss: 0.572 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 92 Validation Loss: 0.590107798576355 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:35:36 or 275736 seconds
# ----------------------------------------
# Epoch[527/23504] Training Loss: 0.588 Reconstruction Loss: 0.571 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Epoch   526: reducing learning rate of group 0 to 3.9063e-06.
# Patience: 93 Validation Loss: 0.5881649851799011 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:35:24 or 275724 seconds
# ----------------------------------------
# Epoch[528/23504] Training Loss: 0.589 Reconstruction Loss: 0.573 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 94 Validation Loss: 0.5901923179626465 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:35:12 or 275712 seconds
# ----------------------------------------
# Epoch[529/23504] Training Loss: 0.588 Reconstruction Loss: 0.571 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 95 Validation Loss: 0.5906804203987122 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:35:00 or 275700 seconds
# ----------------------------------------
# Epoch[530/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 96 Validation Loss: 0.593386173248291 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:34:48 or 275688 seconds
# ----------------------------------------
# Epoch[531/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 97 Validation Loss: 0.592777669429779 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:34:36 or 275676 seconds
# ----------------------------------------
# Epoch[532/23504] Training Loss: 0.588 Reconstruction Loss: 0.572 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 98 Validation Loss: 0.5911793112754822 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:34:24 or 275664 seconds
# ----------------------------------------
# Epoch[533/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.016
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 99 Validation Loss: 0.589155912399292 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:34:12 or 275652 seconds
# ----------------------------------------
# Epoch[534/23504] Training Loss: 0.589 Reconstruction Loss: 0.572 KL Loss: 0.017
# kl_weight: 1.0
# saving ./fluon3dh-last_vae.net
# Patience: 100 Validation Loss: 0.5912113785743713 Min validation loss: 0.5867882966995239
# Time for epoch: 12seconds
# Est remaining time: 3 days, 4:34:00 or 275640 seconds
# ----------------------------------------

# %% [markdown]
# # Plotting losses

# %%
trainHist=np.load(directory_path+"/train_loss.npy")
reconHist=np.load(directory_path+"/train_reco_loss.npy")
klHist=np.load(directory_path+"/train_kl_loss.npy")
valHist=np.load(directory_path+"/val_loss.npy")

# %%
plt.figure(figsize=(18, 3))
plt.subplot(1,3,1)
plt.plot(trainHist,label='training')
plt.plot(valHist,label='validation')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()

plt.subplot(1,3,2)
plt.plot(reconHist,label='training')
plt.xlabel("epochs")
plt.ylabel("reconstruction loss")
plt.legend()

plt.subplot(1,3,3)
plt.plot(klHist,label='training')
plt.xlabel("epochs")
plt.ylabel("KL loss")
plt.legend()
plt.show()
